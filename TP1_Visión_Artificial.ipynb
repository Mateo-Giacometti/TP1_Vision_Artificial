# %% [markdown]
# <center>
#
# # ***Trabajo Práctico Nro 1 - UdeSA Panorámica***
#
# ![image.png](data:image/png;base64,...)
#
# ### **Asignatura:** Visión Artificial.
#
# ### **Alumnos:** Mateo Giacometti y Marcos Piotto.
#
# ### **Profesores:** Gastón Castro, Esteban Uriza y Francisco Gomez Fernandez.
#
# ### **Fecha:** 20/09/2024
#
#
# </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
